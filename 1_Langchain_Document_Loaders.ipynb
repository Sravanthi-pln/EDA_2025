# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravanthi-pln/EDA_2025/blob/main/1_Langchain_Document_Loaders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install -U langchain-community

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(
    ...  # <-- Integration specific parameters here
)
data = loader.load()

# %%
from langchain.document_loaders import TextLoader

# %%
file_path='/content/State_union.txt'
loader = TextLoader(file_path)
print(loader)

# %%
documents = loader.load()
print(documents)

# %%
type(documents)

# %%
print(documents[0])

# %%
print(documents[0].page_content)
print(documents[0].metadata['source'])

# %%
for doc in documents:
    print(f"Document Text: {doc.page_content}")

# %% [markdown]
# # CSV LOADER

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='winequality_red.csv')
data = loader.load()
print(data)
# Out:
# [Document(metadata={'source': 'winequality_red.csv', 'row': 0}, page_content='fixed acidity: 7.4\nvolatile acidity: 0.7\ncitric acid: 0\nresidual sugar: 1.9\nchlorides: 0.076\nfree sulfur dioxide: 11\ntotal sulfur dioxide: 34\ndensity: 0.9978\npH: 3.51\nsulphates: 0.56\nalcohol: 9.4\nquality: 5'), Document(metadata={'source': 'winequality_red.csv', 'row': 1}, page_content='fixed acidity: 7.8\nvolatile acidity: 0.88\ncitric acid: 0\nresidual sugar: 2.6\nchlorides: 0.098\nfree sulfur dioxide: 25\ntotal sulfur dioxide: 67\ndensity: 0.9968\npH: 3.2\nsulphates: 0.68\nalcohol: 9.8\nquality: 5'), Document(metadata={'source': 'winequality_red.csv', 'row': 2}, page_content='fixed acidity: 7.8\nvolatile acidity: 0.76\ncitric acid: 0.04\nresidual sugar: 2.3\nchlorides: 0.092\nfree sulfur dioxide: 15\ntotal sulfur dioxide: 54\ndensity: 0.997\npH: 3.26\nsulphates: 0.65\nalcohol: 9.8\nquality: 5'), Document(metadata={'source': 'winequality_red.csv', 'row': 3}, page_content='fixed acidity: 11.2\nvo
# ...

# %%
len(data) # 1599 rows
# Out:
# 1599

# %%
print(data[0])
print('===============================')
print(data[0].metadata)
print('===============================')
print(data[0].metadata['source'])
# Out:
# page_content='fixed acidity: 7.4
# volatile acidity: 0.7
# citric acid: 0
# residual sugar: 1.9
# chlorides: 0.076
# free sulfur dioxide: 11
# total sulfur dioxide: 34
# density: 0.9978
# pH: 3.51
# sulphates: 0.56
# alcohol: 9.4
# quality: 5' metadata={'source': 'winequality_red.csv', 'row': 0}
# ...
# {'source': 'winequality_red.csv', 'row': 0}
# ...
# winequality_red.csv

# %%
data[0]
# Out:
# Document(metadata={'source': 'winequality_red.csv', 'row': 0}, page_content='fixed acidity: 7.4\nvolatile acidity: 0.7\ncitric acid: 0\nresidual sugar: 1.9\nchlorides: 0.076\nfree sulfur dioxide: 11\ntotal sulfur dioxide: 34\ndensity: 0.9978\npH: 3.51\nsulphates: 0.56\nalcohol: 9.4\nquality: 5')

# %%
print(data[0].page_content)
# Out:
# fixed acidity: 7.4
# volatile acidity: 0.7
# citric acid: 0
# residual sugar: 1.9
# chlorides: 0.076
# free sulfur dioxide: 11
# total sulfur dioxide: 34
# density: 0.9978
# pH: 3.51
# sulphates: 0.56
# alcohol: 9.4
# quality: 5

# %% [markdown]
# # PDF Loader

# %%
from langchain.document_loaders import PyPDFLoader

file_path = 'budget_speech.pdf'
loader = PyPDFLoader(file_path)

# %%
# !pip install pypdf

# %%
documents = loader.load()
documents
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 24.2.159', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-07-23T00:18:17+05:30', 'author': 'hss', 'company': 'HCL Infosystems Limited', 'moddate': '2024-07-23T00:30:42+05:30', 'sourcemodified': 'D:20240722173931', 'source': 'budget_speech.pdf', 'total_pages': 62, 'page': 0, 'page_label': '1'}, page_content='GOVERNMENT OF INDIA\nBUDGET 2024-2025\nSPEECH\nOF\nNIRMALA SITHARAMAN\nMINISTER OF FINANCE\nJuly 23,  2024'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.2.159', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-07-23T00:18:17+05:30', 'author': 'hss', 'company': 'HCL Infosystems Limited', 'moddate': '2024-07-23T00:30:42+05:30', 'sourcemodified': 'D:20240722173931', 'source': 'budget_speech.pdf', 'total_pages': 62, 'page': 1, 'page_label': '2'}, page_content=''),
# ...

# %%
print(len(documents))

# %%
for doc in documents:
    print(f"Page {doc.metadata['page']} Text: {doc.page_content}")
