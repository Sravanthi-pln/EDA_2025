# %% [markdown]
# - Before Model Development
# - We will do EDA: Exploratory Data Analysis
#      - Features(columns) analysis
#      - Categorical, Numerical, Outlier analysis, Bivariate, Multivariate
#      - We will get the insights
# - Feature Engineering
#       - We will  modify the data
#       - Models developed by math
#       - Encoding : convert categorical data to numerical variables
#       -Scaling: All the numerial columns makes under one scale
#       - Transformations: All the maths developed by assumption data follows normal distribution
#               - convert skewed distribution to Normal
# - Feature selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path=r'C:\Users\LG\Documents\DataFiles\Visadataset.csv'
visa_df=pd.read_csv(file_path)
visa_df

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# ## Map method
#
# - create a dictionary lables as keys numbers a values
# - in python index start with 0
# - case status has two lables we need two values 0 and 1
# - certified becomes 0
# - denied becomes 1

# %%
visa_df['case_status'].nunique()
# Out:
# 2

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
dict1={'Certified':0, 'Denied' :1}
visa_df['case_status'] = visa_df['case_status'].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d={}
l=visa_df['continent'].unique()
for i in range(visa_df['continent'].nunique()):
    d[l[i]] = i
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
enumerate(visa_df['continent'].unique().tolist())

# %%
visa_df['continent'].unique().tolist()
# Out:
# ['Asia', 'Africa', 'North America', 'Europe', 'South America', 'Oceania']

# %%
d={val:key for key, val in enumerate(visa_df['continent'].unique().tolist()) }
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
visa_df=pd.read_csv(file_path)
lables=visa_df['case_status'].unique()
print(lables)

d={lables[i]:i for i in range(len(lables))}
print(d)

visa_df['case_status'] = visa_df['case_status'].map(dict1)

visa_df
# Out:
# ['Denied' 'Certified']
# {'Denied': 0, 'Certified': 1}
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df=pd.read_csv(file_path)
for i in cat[1:]:
    lables=visa_df[i].unique()
    d={lables[i]:i for i in range(len(lables))}
    print(d)
    visa_df[i]=visa_df[i].map(d)

visa_df['case_status'].values
# Out:
# {'Asia': 0, 'Africa': 1, 'North America': 2, 'Europe': 3, 'South America': 4, 'Oceania': 5}
# {'High School': 0, "Master's": 1, "Bachelor's": 2, 'Doctorate': 3}
# {'N': 0, 'Y': 1}
# {'N': 0, 'Y': 1}
# {'West': 0, 'Northeast': 1, 'South': 2, 'Midwest': 3, 'Island': 4}
# {'Hour': 0, 'Year': 1, 'Week': 2, 'Month': 3}
# {'Y': 0, 'N': 1}
# {'Denied': 0, 'Certified': 1}
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# ## Label encoder
#
# - Sickit-learn(sklearn)
# - sklearn library is a heart of machine learning in python
# - MLib is heart of machine learning in pyspark
# - sklearn(Library)
# -         preprocess(class)
# -             LabelEncoder(Method)
# -  fit: calculate something
# -  fit_transform : we are modify the values because of calculated one

# %%
from sklearn.preprocessing import LabelEncoder        # Read the method
le=LabelEncoder()                                     # use the method
le.fit_transform(visa_df['case_status'])              #Aply fit transform
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# **OneHotEncoder**

# %% [markdown]
# | Case_status | Case_Status Denined| Case_status_certified       |
# |----------   |-----|------------|
# | Denied      | 1   | 0 |
# | Certified   | 0   | 1 |

# %% [markdown]
# - OneHotEncoder creates new columns that equal t Number of Unique labels
#
# - one disadvantage is data dimensions will be increased
#
# - More dimensions leads to more processing time leads to bigger infra memory
#
# - This is called as **Curse of dimensionality**
#
# - Advantage
#
#
#     - generally ML algorithms Excects no correlation between input columns
#
#     - when one column value available and at a same time another colum value not available means both are independent each other

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pd.get_dummies(visa_df,columns=cat[1:])
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                 False            True             False
# 1                 False            True             False
# ...

# %%
pd.get_dummies(visa_df,columns=cat[1:],dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %% [markdown]
# - if data is on ordinal go with LabelEncoder
# - if data is Nominal go with oneHotEnchoder
# - if Lables are more go with LabelEncoder
# - if lables are less go with oneHotEncoder
